# %%
from sklearn.datasets import load_iris
#from sklearn import tree
from sklearn import tree
# import sklearn
import graphviz # for plot a decission tree

iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)

#Plot the decision tree
 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris") 

dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor
Spyder Editor

This is a temporary script file.
"""
from sklearn import tree
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


df1=pd.read_csv("D:\Python_Code\Python_MIS\so_mis.csv",'utf-8', engine = 'python', header=0, delimiter=',')
print (df1.columns)
print(len(df1.columns))
X = df1[df1.columns[1:36]].values
print(X)
Y = df1[df1.columns[36]].values
print(Y)
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size = 0.3)
print(Xtrain.shape)
print(Xtest.shape)
clf = tree.DecisionTreeClassifier(criterion= "entropy", max_depth = 5)
clf.fit(Xtrain, Ytrain)

Ypred = clf.predict(Xtest)
print(Ypred)

print (accuracy_score(Ytest, Ypred, normalize=False))
count = 0
for i in range(len(Ypred)):
    if Ypred[i] == Ytest[i]:
        count += 1
print('Độ chính của thuật toán:',count*100/len(Ypred))
import graphviz
#dot_data = tree.export_graphviz(clf, out_file=None)
#graph = graphviz.Source(dot_data)
#graph.render("laokhoa_sos")
dot_data = tree.export_graphviz(clf, out_file=None,
                         feature_names= df1.columns[1:36],
                         class_names= list(set(Ytrain)),
                         filled=True, rounded=True,
                         special_characters=True)
graph = graphviz.Source(dot_data)
#graph.render("shh-ths")
graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-944a40e72036> in <module>
#      12
#      13
# ---> 14 df1=pd.read_csv("D:\Python_Code\Python_MIS\so_mis.csv",'utf-8', engine = 'python', header=0, delimiter=',')
#      15 print (df1.columns)
#      16 print(len(df1.columns))
#
# c:\users\hungnd\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\users\hungnd\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\users\hungnd\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\users\hungnd\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1145                     ' "python-fwf")'.format(engine=engine)
#    1146                 )
# -> 1147             self._engine = klass(self.f, **self.options)
#    1148
#    1149     def _failover_to_python(self):
#
# c:\users\hungnd\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2291             encoding=self.encoding,
#    2292             compression=self.compression,
# -> 2293             memory_map=self.memory_map,
#    2294         )
#    2295         self.handles.extend(handles)
#
# c:\users\hungnd\appdata\local\programs\python\python37\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     400         elif is_text:
#     401             # No explicit encoding
# --> 402             f = open(path_or_buf, mode, errors="replace", newline="")
#     403         else:
#     404             # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Python_Code\\Python_MIS\\so_mis.csv'

# %%
from graphviz import Source

src = Source('digraph "the holy hand grenade" { rankdir=LR; 1 -> 2 -> 3 -> lob }')
src

# %%
# http://www.graphviz.org/pdf/dotguide.pdf Figure 20

from graphviz import Digraph
g = Digraph('G', filename ='cluster_edge.gv')
#g.attr(compound='true')
with g.subgraph(name = 'cluster0') as c:
    c.edges(['ab', 'ac', 'bd', 'cd'])
with g.subgraph(name = 'cluster1') as c:
    c.edges(['eg', 'ef'])

g.edge('b', 'f', lhead='cluster1')
g.edge('d', 'e')
g.edge('c', 'g', ltail='cluster0', lhead='cluster1')
g.edge('c', 'e', ltail='cluster0')
g.edge('d', 'h')

g

# %%
# http://www.graphviz.org/content/fsm

from graphviz import Digraph

f = Digraph('finite_state_machine', filename='fsm.gv')
#f.attr(rankdir='LR', size='8,5')

f.attr('node', shape='doublecircle')
f.node('LR_0')
f.node('LR_3')
f.node('LR_4')
f.node('LR_8')

f.attr('node', shape='circle')
f.edge('LR_0', 'LR_2', label='SS(B)')
f.edge('LR_0', 'LR_1', label='SS(S)')
f.edge('LR_1', 'LR_3', label='S($end)')
f.edge('LR_2', 'LR_6', label='SS(b)')
f.edge('LR_2', 'LR_5', label='SS(a)')
f.edge('LR_2', 'LR_4', label='S(A)')
f.edge('LR_5', 'LR_7', label='S(b)')
f.edge('LR_5', 'LR_5', label='S(a)')
f.edge('LR_6', 'LR_6', label='S(b)')
f.edge('LR_6', 'LR_5', label='S(a)')
f.edge('LR_7', 'LR_8', label='S(b)')
f.edge('LR_7', 'LR_5', label='S(a)')
f.edge('LR_8', 'LR_6', label='S(b)')
f.edge('LR_8', 'LR_5', label='S(a)')

f

# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')


dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

dot

# %%
from
